# %%
import json
import sqlite3

conn = sqlite3.connect('rosterdb.sqlite')
cur = conn.cursor()

# Do some setup
cur.executescript('''
DROP TABLE IF EXISTS User;
DROP TABLE IF EXISTS Member;
DROP TABLE IF EXISTS Course;

CREATE TABLE User (
    id     INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name   TEXT UNIQUE
);

CREATE TABLE Course (
    id     INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    title  TEXT UNIQUE
);

CREATE TABLE Member (
    user_id     INTEGER,
    course_id   INTEGER,
    role        INTEGER,
    PRIMARY KEY (user_id, course_id)
)
''')

# fname = input('Enter file name: ')
# if len(fname) < 1:
fname = 'roster_data.json'

# [
#   [ "Charley", "si110", 1 ],
#   [ "Mea", "si110", 0 ],

str_data = open(fname).read()
json_data = json.loads(str_data)

for entry in json_data:
    print(entry)
    name = entry[0];
    title = entry[1];
    role = entry[2];
#     print((name, title))

    cur.execute('''INSERT OR IGNORE INTO User (name)
        VALUES ( ? )''', ( name, ) )
    cur.execute('SELECT id FROM User WHERE name = ? ', (name, ))
    user_id = cur.fetchone()[0]

    cur.execute('''INSERT OR IGNORE INTO Course (title)
        VALUES ( ? )''', ( title, ) )
    cur.execute('SELECT id FROM Course WHERE title = ? ', (title, ))
    course_id = cur.fetchone()[0]

    cur.execute('''INSERT OR REPLACE INTO Member
        (user_id, course_id,role) VALUES ( ?, ?,? )''',
        ( user_id, course_id, role ) )

conn.commit()
# Out:
# ['Johnpaul', 'si110', 1]
# ['Shantelle', 'si110', 0]
# ['Hayden', 'si110', 0]
# ['Lynsie', 'si110', 0]
# ['Declyan', 'si110', 0]
# ['Chidera', 'si110', 0]
# ['Ardal', 'si110', 0]
# ['Scott', 'si110', 0]
# ['Teri', 'si110', 0]
# ['Kylie', 'si110', 0]
# ['Sameera', 'si110', 0]
# ['Nicky', 'si110', 0]
# ['Kriss', 'si110', 0]
# ['Jaiha', 'si110', 0]
# ['Braden', 'si110', 0]
# ['Karamvir', 'si110', 0]
# ['Nikhil', 'si110', 0]
# ['Jensen', 'si110', 0]
# ['Savanna', 'si110', 0]
# ['Kacper', 'si110', 0]
# ['Kym', 'si110', 0]
# ['Rhuan', 'si110', 0]
# ['Jordanne', 'si110', 0]
# ['Airidas', 'si110', 0]
# ['Rylee', 'si110', 0]
# ['Arrham', 'si110', 0]
# ['Hijab', 'si110', 0]
# ['Bethany', 'si110', 0]
# ['Braeden', 'si110', 0]
# ['Shahmir', 'si110', 0]
# ['Roos', 'si110', 0]
# ['Kiah', 'si110', 0]
# ['Leanna', 'si110', 0]
# ['Monika', 'si110', 0]
# ['Zayn', 'si110', 0]
# ['Winnifred', 'si110', 0]
# ['Humayra', 'si110', 0]
# ['Kajetan', 'si110', 0]
# ['Cadie', 'si110', 0]
# ['Luis', 'si110', 0]
# ['Caragh', 'si110', 0]
# ['Torsten', 'si110', 0]
# ['Leea', 'si110', 0]
# ['Mungo', 'si110', 0]
# ['Kaydn', 'si110', 0]
# ['Zennon', 'si110', 0]
# ['Iris', 'si110', 0]
# ['Malak', 'si110', 0]
# ['Gurthar', 'si106', 1]
# ['Temba', 'si106', 0]
# ['Mikella', 'si106', 0]
# ['Orley', 'si106', 0]
# ['Sister', 'si106', 0]
# ['Jaydyn', 'si106', 0]
# ['Del', 'si106', 0]
# ['Amaney', 'si106', 0]
# ['Laticha', 'si106', 0]
# ['Robertjohn', 'si106', 0]
# ['Zuhrah', 'si106', 0]
# ['Jae', 'si106', 0]
# ['Jaida', 'si106', 0]
# ['Brea', 'si106', 0]
# ['Una', 'si106', 0]
# ['Keilidh', 'si106', 0]
# ['Dolci', 'si106', 0]
# ['Lottie', 'si106', 0]
# ['Ama', 'si106', 0]
# ['Beatrice', 'si106', 0]
# ['Luic', 'si106', 0]
# ['Ramone', 'si106', 0]
# ['Maija', 'si106', 0]
# ['Reynelle', 'si106', 0]
# ['Ogheneochuko', 'si106', 0]
# ['Shannon', 'si106', 0]
# ['Ailiegh', 'si206', 1]
# ['Kasey', 'si206', 0]
# ['Kiaran', 'si206', 0]
# ['Japleen', 'si206', 0]
# ['Orin', 'si206', 0]
# ['Baileigh', 'si206', 0]
# ['Charley', 'si206', 0]
# ['Hind', 'si206', 0]
# ['Lida', 'si206', 0]
# ['Codie', 'si206', 0]
# ['Liesje', 'si206', 0]
# ['Janey', 'si206', 0]
# ['Manar', 'si206', 0]
# ['Keiryn', 'si206', 0]
# ['Elise', 'si206', 0]
# ['Corin', 'si206', 0]
# ['Euphemia', 'si206', 0]
# ['Isabel', 'si206', 0]
# ['Florin', 'si206', 0]
# ['Hashem', 'si206', 0]
# ['Lois', 'si206', 0]
# ['Ida', 'si206', 0]
# ['Eoghain', 'si206', 0]
# ['Kornelija', 'si206', 0]
# ['Addisson', 'si206', 0]
# ['Murrough', 'si206', 0]
# ['Albert', 'si206', 0]
# ['Fionnah', 'si206', 0]
# ['Kendall', 'si206', 0]
# ['Emilie', 'si206', 0]
# ['Harleigh', 'si206', 0]
# ['Zayne', 'si206', 0]
# ['Charlay', 'si206', 0]
# ['Kalyana', 'si206', 0]
# ['Oilibhear', 'si206', 0]
# ['Rebbecah', 'si206', 0]
# ['Naif', 'si206', 0]
# ['Amaney', 'si206', 0]
# ['Lancelot', 'si206', 0]
# ['Prentice', 'si206', 0]
# ['Iseabel', 'si206', 0]
# ['Lydia', 'si206', 0]
# ['Abubakar', 'si206', 0]
# ['Nabiha', 'si206', 0]
# ['Vasemaca', 'si206', 0]
# ['Micaylah', 'si206', 0]
# ['Wu', 'si206', 0]
# ['Roen', 'si206', 0]
# ['Rhia', 'si301', 1]
# ['Kelsiee', 'si301', 0]
# ['Julia', 'si301', 0]
# ['Sammy', 'si301', 0]
# ['Christie', 'si301', 0]
# ['Aarez', 'si301', 0]
# ['Rayyan', 'si301', 0]
# ['Aulay', 'si301', 0]
# ['Benoit', 'si301', 0]
# ['Bezalel', 'si301', 0]
# ['Ronald', 'si301', 0]
# ['Muzammil', 'si301', 0]
# ['Amrita', 'si301', 0]
# ['Darcy', 'si301', 0]
# ['Luciano', 'si301', 0]
# ['Ata', 'si301', 0]
# ['Milla', 'si301', 0]
# ['Riley', 'si301', 0]
# ['Ubayd', 'si301', 0]
# ['Burak', 'si301', 0]
# ['Philippos', 'si301', 0]
# ['Johansson', 'si301', 0]
# ['Stacy', 'si301', 0]
# ['Alvin', 'si301', 0]
# ['Rhuaridh', 'si301', 0]
# ['Conghaile', 'si301', 0]
# ['Haroon', 'si301', 0]
# ['Natania', 'si301', 0]
# ['Enrika', 'si301', 0]
# ['Klara', 'si301', 0]
# ['Robbie', 'si301', 0]
# ['Phebe', 'si301', 0]
# ['Rohanne', 'si301', 0]
# ['Nathalie', 'si301', 0]
# ['Alaa', 'si301', 0]
# ['Eileen', 'si301', 0]
# ['Masood', 'si301', 0]
# ['Hasan', 'si301', 0]
# ['Nolan', 'si301', 0]
# ['Sidney', 'si310', 1]
# ['Japjeet', 'si310', 0]
# ['Rohaan', 'si310', 0]
# ['Tadd', 'si310', 0]
# ['Amyrose', 'si310', 0]
# ['Bernadette', 'si310', 0]
# ['Roni', 'si310', 0]
# ['Michat', 'si310', 0]
# ['Kurtis', 'si310', 0]
# ['Avesta', 'si310', 0]
# ['Samantha', 'si310', 0]
# ['Abhy', 'si310', 0]
# ['Kaya', 'si310', 0]
# ['Olaoluwapolorimi', 'si310', 0]
# ['Chloe', 'si310', 0]
# ['Mila', 'si310', 0]
# ['Elisa', 'si310', 0]
# ['Dougray', 'si310', 0]
# ['Eesa', 'si310', 0]
# ['Santino', 'si310', 0]
# ['Siouxsie', 'si310', 0]
# ['Eliza', 'si310', 0]
# ['Lewie', 'si310', 0]
# ['Jacob', 'si310', 0]
# ['Macaulay', 'si310', 0]
# ['Ailin', 'si310', 0]
# ['Aleah', 'si310', 0]
# ['Jaden', 'si310', 0]
# ['Maddison', 'si310', 0]
# ['Cesare', 'si310', 0]
# ['Angelina', 'si310', 0]
# ['Hollyanne', 'si310', 0]
# ['Dannii', 'si310', 0]
# ['Saschamarie', 'si310', 0]
# ['Indi', 'si310', 0]
# ['Nasifa', 'si310', 0]
# ['Macy', 'si310', 0]
# ['Kane', 'si310', 0]
# ['Kaydyne', 'si310', 0]
# ['Maitlind', 'si310', 0]
# ['Mcbride', 'si310', 0]
# ['Lida', 'si310', 0]
# ['Rhiona', 'si310', 0]
# ['Ayesha', 'si310', 0]
# ['Shyam', 'si334', 1]
# ['Kai', 'si334', 0]
# ['Breagha', 'si334', 0]
# ['Saicu', 'si334', 0]
# ['Kimi', 'si334', 0]
# ['Hamza', 'si334', 0]
# ['Adegbolahan', 'si334', 0]
# ['Johanna', 'si334', 0]
# ['Kaleena', 'si334', 0]
# ['Keyra', 'si334', 0]
# ['Israel', 'si334', 0]
# ['Chen', 'si334', 0]
# ['Scot', 'si334', 0]
# ['Jaelyn', 'si334', 0]
# ['Elvita', 'si334', 0]
# ['Halle', 'si334', 0]
# ['Shawn', 'si334', 0]
# ['Antony', 'si334', 0]
# ['Ama', 'si334', 0]
# ['Katelyne', 'si334', 0]
# ['Orlaidh', 'si334', 0]
# ['Navdeep', 'si334', 0]
# ['Brendon', 'si334', 0]
# ['Angaly', 'si334', 0]
# ['Levi', 'si334', 0]
# ['Dex', 'si334', 0]
# ['Saphyre', 'si334', 0]
# ['Annie', 'si334', 0]
# ['Meadow', 'si334', 0]
# ['Kenton', 'si334', 0]
# ['Steffie', 'si334', 0]
# ['Preston', 'si334', 0]
# ['Kaska', 'si334', 0]
# ['Coll', 'si334', 0]
# ['Kasim', 'si334', 0]
# ['Jake', 'si334', 0]
# ['Aleksandar', 'si334', 0]
# ['Caitlyn', 'si363', 1]
# ['Lowri', 'si363', 0]
# ['Trent', 'si363', 0]
# ['Anir', 'si363', 0]
# ['Fodeba', 'si363', 0]
# ['Kirstyn', 'si363', 0]
# ['Sylvana', 'si363', 0]
# ['Teigan', 'si363', 0]
# ['Eqlaas', 'si363', 0]
# ['Shenuk', 'si363', 0]
# ['Kaidinn', 'si363', 0]
# ['Jasmine', 'si363', 0]
# ['Finn', 'si363', 0]
# ['Waqaas', 'si363', 0]
# ['Karimas', 'si363', 0]
# ['Ayeisha', 'si363', 0]
# ['Reis', 'si363', 0]
# ['Roberta', 'si363', 0]
# ['Aliekber', 'si363', 0]
# ['Brandonlee', 'si363', 0]
# ['Lyall', 'si363', 0]
# ['Kjae', 'si363', 0]
# ['Lynn', 'si363', 0]
# ['Marius', 'si363', 0]
# ['Ireayomide', 'si363', 0]
# ['Se', 'si363', 0]
# ['Amna', 'si363', 0]
# ['Frederick', 'si363', 0]
# ['Afrina', 'si363', 0]
# ['Alicja', 'si364', 1]
# ['Soukina', 'si364', 0]
# ['Zerah', 'si364', 0]
# ['Chu', 'si364', 0]
# ['Bradyn', 'si364', 0]
# ['Adelaide', 'si364', 0]
# ['Pamela', 'si364', 0]
# ['Kerrie', 'si364', 0]
# ['Kierin', 'si364', 0]
# ['Kihanna', 'si364', 0]
# ['Sukhveer', 'si364', 0]
# ['Kaleigh', 'si364', 0]
# ['Shinade', 'si364', 0]
# ['Aileigh', 'si364', 0]
# ['Presley', 'si364', 0]
# ['Rayan', 'si364', 0]
# ['Elita', 'si364', 0]
# ['Akam', 'si364', 0]
# ['Jacques', 'si364', 0]
# ['Nawfal', 'si364', 0]
# ['Zuzanna', 'si364', 0]
# ['Macy', 'si364', 0]
# ['Saphyre', 'si364', 0]
# ['Kendall', 'si422', 1]
# ['Sheigh', 'si422', 0]
# ['Kashuf', 'si422', 0]
# ['Lynn', 'si422', 0]
# ['Kaidyn', 'si422', 0]
# ['Tabitha', 'si422', 0]
# ['Matt', 'si422', 0]
# ['Orran', 'si422', 0]
# ['Lukasz', 'si422', 0]
# ['Kayleb', 'si422', 0]
# ['Keirra', 'si422', 0]
# ['Zuriel', 'si422', 0]
# ['Makin', 'si422', 0]
# ['Alex', 'si422', 0]
# ['Maisum', 'si422', 0]
# ['Leigha', 'si422', 0]
# ['Holly', 'si422', 0]
# ['Oluwademilade', 'si422', 0]
# ['Aeryn', 'si422', 0]
# ['Jena', 'si422', 0]
# ['Reuben', 'si422', 0]
# ['Kenzi', 'si422', 0]
# ['Zoubaeir', 'si422', 0]
# ['Cheyanne', 'si422', 0]
# ['Muir', 'si422', 0]
# ['Momina', 'si422', 0]
# ['Francesco', 'si422', 0]
# ['Chizaram', 'si422', 0]
# ['Tembe', 'si422', 0]
# ['Megha', 'si422', 0]
# ['Eirian', 'si422', 0]
# ['Hanna', 'si422', 0]
# ['Rafi', 'si422', 0]
# ['Madinah', 'si422', 0]
# ['Kaison', 'si422', 0]
# ['Michela', 'si422', 0]
# ['Evan', 'si422', 0]
# ['Antigone', 'si422', 0]
# ['Maxwell', 'si422', 0]
# ['Bruno', 'si422', 0]
# ['Averon', 'si422', 0]
# ['Shikha', 'si422', 0]
# ['Gigha', 'si430', 1]
# ['Mustapha', 'si430', 0]
# ['Aazaan', 'si430', 0]
# ['Zanab', 'si430', 0]
# ['Derryn', 'si430', 0]
# ['Chrissie', 'si430', 0]
# ['Codi', 'si430', 0]
# ['Chenille', 'si430', 0]
# ['Kiranpreet', 'si430', 0]
# ['Cathal', 'si430', 0]
# ['Raniyah', 'si430', 0]
# ['Lucien', 'si430', 0]
# ['Jody', 'si430', 0]
# ['Sajida', 'si430', 0]
# ['Adnan', 'si430', 0]
# ['Deegan', 'si430', 0]
# ['Kaydi', 'si430', 0]
# ['Efe', 'si430', 0]
# ['Gabby', 'si430', 0]
# ['Abdulmalik', 'si430', 0]
# ['Angeline', 'si430', 0]
# ['Elysa', 'si430', 0]
# ['Rose', 'si430', 0]
# ['Eamonn', 'si430', 0]
# ['Salsabeel', 'si430', 0]
# ['Zeek', 'si430', 0]
# ['Rebbecca', 'si430', 0]
# ['Luighsighe', 'si430', 0]
# ['Tailee', 'si430', 0]
# ['Fruin', 'si430', 0]
# ['Sana', 'si430', 0]
# ['Macy', 'si430', 0]
# ['Shyam', 'si430', 0]

# %%
cur.execute('''SELECT hex(User.name || Course.title || Member.role ) AS X FROM 
    User JOIN Member JOIN Course 
    ON User.id = Member.user_id AND Member.course_id = Course.id
    ORDER BY X''')

# %%
for row in cur:
    print(row)
# Out:
# ('416172657A736933303130',)
# ('41617A61616E736934333030',)
# ('416264756C6D616C696B736934333030',)
# ('41626879736933313030',)
# ('41627562616B6172736932303630',)
# ('4164646973736F6E736932303630',)
# ('41646567626F6C6168616E736933333430',)
# ('4164656C61696465736933363430',)
# ('41646E616E736934333030',)
# ('416572796E736934323230',)
# ('416672696E61736933363330',)
# ('41696C65696768736933363430',)
# ('41696C69656768736932303631',)
# ('41696C696E736933313030',)
# ('41697269646173736931313030',)
# ('416B616D736933363430',)
# ('416C6161736933303130',)
# ('416C62657274736932303630',)
# ('416C656168736933313030',)
# ('416C656B73616E646172736933333430',)
# ('416C6578736934323230',)
# ('416C69636A61736933363431',)
# ('416C69656B626572736933363330',)
# ('416C76696E736933303130',)
# ('416D616E6579736931303630',)
# ('416D616E6579736932303630',)
# ('416D61736931303630',)
# ('416D61736933333430',)
# ('416D6E61736933363330',)
# ('416D72697461736933303130',)
# ('416D79726F7365736933313030',)
# ('416E67616C79736933333430',)
# ('416E67656C696E61736933313030',)
# ('416E67656C696E65736934333030',)
# ('416E6972736933363330',)
# ('416E6E6965736933333430',)
# ('416E7469676F6E65736934323230',)
# ('416E746F6E79736933333430',)
# ('417264616C736931313030',)
# ('41727268616D736931313030',)
# ('417461736933303130',)
# ('41756C6179736933303130',)
# ('417665726F6E736934323230',)
# ('417665737461736933313030',)
# ('41796569736861736933363330',)
# ('417965736861736933313030',)
# ('4261696C65696768736932303630',)
# ('4265617472696365736931303630',)
# ('42656E6F6974736933303130',)
# ('4265726E616465747465736933313030',)
# ('42657468616E79736931313030',)
# ('42657A616C656C736933303130',)
# ('42726164656E736931313030',)
# ('42726164796E736933363430',)
# ('4272616564656E736931313030',)
# ('4272616E646F6E6C6565736933363330',)
# ('42726561676861736933333430',)
# ('42726561736931303630',)
# ('4272656E646F6E736933333430',)
# ('4272756E6F736934323230',)
# ('427572616B736933303130',)
# ('4361646965736931313030',)
# ('436169746C796E736933363331',)
# ('436172616768736931313030',)
# ('43617468616C736934333030',)
# ('436573617265736933313030',)
# ('436861726C6179736932303630',)
# ('436861726C6579736932303630',)
